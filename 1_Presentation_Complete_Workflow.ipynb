# %% [markdown]
# # Corti API Workflow Demo
# ## Audio → Transcript → Facts → SOAP Document
#
# This notebook demonstrates the complete workflow of processing medical audio through the Corti API to generate a structured SOAP document.
#
# **Each step is broken down for easy testing, troubleshooting, and showcasing.**

# %% [markdown]
# ---
# ## Setup & Authentication
#
# Initialize and authenticate the Corti API client via the OAuth2 handshake. The underlying authentication code is located in corti_client.py.

# %%
from dotenv import load_dotenv
from corti_client import CortiClient
import requests
import time
import uuid
import json
import os

# %%
# Load credentials
load_dotenv()

# Initialize and authenticate
client = CortiClient()
client.authenticate()

print("✓ Successfully authenticated with Corti API")
print(f"Environment: {client.environment}")
print(f"Tenant: {client.tenant_name}")
# Out:
# ✓ Successfully authenticated with Corti API
# Environment: eu
# Tenant: base

# %% [markdown]
# ---
# ## Assumptions & Design Decisions
#
# ### API Assumptions:
# - OAuth2 token-based authentication with client credentials
# - Interaction lifecycle management required for all operations
# - Asynchronous transcription processing with polling mechanism
# - Primary language: English (en-US)
#
# ### Edge Cases Handled & Implementation Choices:
# - **Transcription timeout**: Maximum wait time of 300 seconds with 3-second polling intervals
# - **Large audio files**: Upload timeout set to 60 seconds
# - **Status checking for transcription**: Handles 'processing', 'completed', and 'failed' states
# - **Response parsing**: Robust extraction of nested JSON structures
#
# - **Fact extraction**: Added fact extraction from transcription to enhance the clinical document content
# - **Mono-channel and no Diarization**: Set the transcription with minimal configuration so that it's easy to upload MP3 audio for transcription
# - **Structured facts**: Using `{text, group, source}` format for compatibility with SOAP creation

# %% [markdown]
# ---
# # Step 1: Audio → Transcript
#
# Breaking down the transcription process into individual steps:
# 1. Create interaction
# 2. Upload audio recording
# 3. Request transcription
# 4. Poll for completion
# 5. Retrieve transcript
# 6. Extract text
# 7. Save to file

# %% [markdown]
# ### Step 1.1: Create Interaction
# **API**: `POST /interactions`
#
# Create a new interaction session with patient and encounter information.

# %%
headers = client.get_headers(include_tenant=True)

# Create interaction payload
interaction_payload = {
    "encounter": {
        "identifier": str(uuid.uuid4()),
        "status": "planned",
        "type": "first_consultation"
    },
    "patient": {
        "identifier": str(uuid.uuid4()),
        "gender": "unknown"
    }
}

print("Creating interaction...")
response = requests.post(
    f"{client.api_url}/interactions",
    headers=headers,
    json=interaction_payload,
    timeout=30
)
response.raise_for_status()
interaction_data = response.json()
interaction_id = interaction_data["interactionId"]

print(f"✓ Interaction created successfully!")
print(f"Interaction ID: {interaction_id}")
print(f"\nSample response:")
print(json.dumps(interaction_data, indent=2)[:500] + "...")
# Out:
# Creating interaction...
# ✓ Interaction created successfully!
# Interaction ID: bdabae9b-efd2-4ff2-9488-b2b3df0b055d
#
# Sample response:
# {
#   "interactionId": "bdabae9b-efd2-4ff2-9488-b2b3df0b055d",
#   "websocketUrl": "wss://api.eu.corti.app/audio-bridge/v2/interactions/bdabae9b-efd2-4ff2-9488-b2b3df0b055d/streams?tenant-name=base"
# }...

# %% [markdown]
# ### Step 1.2: Upload Audio File
# **API**: `POST /interactions/{id}/recordings/`
#
# Upload the audio file to the interaction.

# %%
# Specify audio file path
audio_path = "data/samples/TalkCPR- A real patient and doctor interaction filmed.mp3"

print(f"Uploading audio file: {audio_path}")
print(f"File size: {os.path.getsize(audio_path) / (1024*1024):.2f} MB\n")

with open(audio_path, 'rb') as audio_file:
    files = {'file': audio_file}
    upload_headers = {
        "Authorization": f"Bearer {client.access_token}",
        "Tenant-Name": client.tenant_name
    }

    response = requests.post(
        f"{client.api_url}/interactions/{interaction_id}/recordings/",
        headers=upload_headers,
        files=files,
        timeout=60
    )
    response.raise_for_status()
    recording_data = response.json()
    recording_id = recording_data["recordingId"]

print(f"✓ Audio uploaded successfully!")
print(f"Recording ID: {recording_id}")
# Out:
# Uploading audio file: data/samples/TalkCPR- A real patient and doctor interaction filmed.mp3
# File size: 34.82 MB
#
# ✓ Audio uploaded successfully!
# Recording ID: 658acc49-eaa0-4df9-b022-7ced840562c6

# %% [markdown]
# ### Step 1.3: Request Transcription
# **API**: `POST /interactions/{id}/transcripts`
#
# Submit a transcription request for the uploaded audio.

# %%
# Transcription configuration
transcript_payload = {
    "recordingId": recording_id,
    "primaryLanguage": "en",
    "isDictation": False,
    "isMultichannel": False,
    "diarize": True
}


print("Requesting transcription...")
print(f"Configuration: {json.dumps(transcript_payload, indent=2)}\n")

response = requests.post(
    f"{client.api_url}/interactions/{interaction_id}/transcripts",
    headers=headers,
    json=transcript_payload,
    timeout=30
)
response.raise_for_status()
transcript_data = response.json()
transcript_id = transcript_data["id"]

print(f"✓ Transcription requested successfully!")
print(f"Transcript ID: {transcript_id}")
# Out:
# Requesting transcription...
# Configuration: {
#   "recordingId": "658acc49-eaa0-4df9-b022-7ced840562c6",
#   "primaryLanguage": "en",
#   "isDictation": false,
#   "isMultichannel": false,
#   "diarize": true
# }
#
# ✓ Transcription requested successfully!
# Transcript ID: 87d2b74b-2245-4ae0-a1d5-a4acf2277c41

# %% [markdown]
# ### Step 1.4: Poll for Transcription Status
# Wait for the transcription to complete by polling the status endpoint.

# %%
print("Polling for transcription completion...")
print("(This may take 30-120 seconds depending on audio length)\n")

max_wait_seconds = 300
poll_interval = 3
start_time = time.time()

while time.time() - start_time < max_wait_seconds:
    # Check status
    response = requests.get(
        f"{client.api_url}/interactions/{interaction_id}/transcripts/{transcript_id}/status",
        headers=headers,
        timeout=10
    )
    response.raise_for_status()
    status_data = response.json()
    status = status_data.get('status', 'processing')

    elapsed = int(time.time() - start_time)
    print(f"[{elapsed}s] Status: {status}")

    if status == 'completed':
        print("\n✓ Transcription completed!")
        break
    elif status == 'failed':
        error_msg = status_data.get('error', 'Unknown error')
        raise Exception(f"Transcript processing failed: {error_msg}")

    time.sleep(poll_interval)
else:
    raise TimeoutError(f"Transcript did not complete within {max_wait_seconds} seconds")

print(f"\nFinal status response:")
print(json.dumps(status_data, indent=2))
# Out:
# Polling for transcription completion...
# (This may take 30-120 seconds depending on audio length)
#
# [0s] Status: completed
#
# ✓ Transcription completed!
#
# Final status response:
# {
#   "status": "completed"
# }

# %% [markdown]
# ### Step 1.5: Retrieve Full Transcript
# Get the complete transcript data from the API.

# %%
print("Retrieving full transcript...")

response = requests.get(
    f"{client.api_url}/interactions/{interaction_id}/transcripts/{transcript_id}",
    headers=headers,
    timeout=50
)
response.raise_for_status()
transcript_result = response.json()

print("✓ Transcript retrieved successfully!")
print(f"\nTranscript contains {len(transcript_result.get('transcripts', []))} segments")
print(f"\nFull transcript structure:")
print(json.dumps(transcript_result, indent=2)[:1000] + "..." if len(json.dumps(transcript_result)) > 1000 else json.dumps(transcript_result, indent=2))
# Out:
# Retrieving full transcript...
# ✓ Transcript retrieved successfully!
#
# Transcript contains 216 segments
#
# Full transcript structure:
# {
#   "id": "87d2b74b-2245-4ae0-a1d5-a4acf2277c41",
#   "metadata": {
#     "participantsRoles": null
#   },
#   "transcripts": [
#     {
#       "channel": 0,
#       "participant": 0,
#       "speakerId": 0,
#       "text": "Afternoon,",
#       "start": 4160,
#       "end": 4660
#     },
#     {
#       "channel": 0,
#       "participant": 0,
#       "speakerId": 0,
#       "text": "Kat. Nice to see you. Nice to catch up again. How are you? I'm good. Thank you. How are you? Not too bad. Not too bad. Not too bad. I'm in my office in",
#       "start": 4960,
#       "end": 15305
#     },
#     {
#       "channel": 0,
#       "participant": 0,
#       "speakerId": 0,
#       "text": "Wilindra Cancer Hospital as you as you can see. Very nice.",
#       "start": 15685,
#       "end": 19490
#     },
#     {
#       "channel": 0,
#       "participant": 0,
#       "speakerId": 0,
#       "text": "And, good to see you,",
#       "start": 20369,
#       "end": 22050
#     },
#     {
#       "channel": 0,
#       "participant": 0,
#       "speakerId": 0,
#       "text": "at h...

# %% [markdown]
# ### Step 1.6: Extract Transcript Text
# **Result**: Final transcribed text ready for fact extraction

# %%
# Extract text from transcript segments
transcript_parts = []

if 'transcripts' in transcript_result:
    for entry in transcript_result['transcripts']:
        if 'text' in entry:
            transcript_parts.append(entry['text'])

transcript_text = " ".join(transcript_parts)

print("TRANSCRIPT TEXT:")
print("=" * 70)
print(transcript_text)
print("=" * 70)
print(f"\nLength: {len(transcript_text)} characters")
print(f"Word count: ~{len(transcript_text.split())} words")
# Out:
# TRANSCRIPT TEXT:
# ======================================================================
# Afternoon, Kat. Nice to see you. Nice to catch up again. How are you? I'm good. Thank you. How are you? Not too bad. Not too bad. Not too bad. I'm in my office in Wilindra Cancer Hospital as you as you can see. Very nice. And, good to see you, at home as well. The the new world of of, outpatient appointments via via video link, isn't it? Indeed. Yes. Good to catch up with you. I think last time we saw each other face to face. I think the focus was a bit sort of your pain management. I think today the focus was going to be, I was going to talk a little bit about discussing future treatments as such, if that is okay with you. Yeah, sounds good. Do you mind, just for the purpose of the consultation, do you mind just quickly summarizing where things are at at the moment? Would that be okay? Yeah, no, that's fine. So I'm Kat. I am thirty nine. I had to think about that then. I'm thirty nine, and I have stage four breast cancer. I was first diagnosed nine years ago, and had, a whole lot of treatment then. And then four years ago received my secondary diagnosis, where the breast cancer has since spread to other parts of my body like my lungs and my bones. I've now been having treatment, so palliative chemotherapy, now for four years and I'm now on my fourth line chemotherapy agent. And yeah, it's sort of a bit of a ongoing, ongoing profession or ongoing commitment, this chemotherapy now. So yeah, four years in, still on chemotherapy. And then we started meeting with regards to managing my symptoms, specifically pain, but actually that's branched out into other things and that's been quite useful. And here we are today. When did we first meet? I think it was about two years ago or what? Yeah. I think so. And it was it was specifically for the pain in my arm, wasn't it, at that point? I think that was the reason we we first started meeting. Yeah. And actually, that's been less of a focus more recently and that's been, that's actually not really an issue anymore, but it's probably because we've, with your help, we've managed it. And, again, thanks for, agreeing to, to doing this, this video as well. As, as you know, we're sort of hoping to increase the amount of videos we're doing with regard to advanced care planning conversations and the Talk CPR video website as well. So I'm really grateful to you for that. Yes, it's alright. Thank you very much. So we've known each other for a little while and I've met your partner as well. We did. Tarek. I think I've alluded to the fact that at some point I'd want to discuss maybe about future treatments, things that you would consider potentially appropriate in your care and things where you may have thoughts or knowledge gaps potentially or whatever in terms of addressing them. Yeah, I mean, as you can see, sometimes I find this not an easy one to bring up in consultations because I think everyone sometimes gets a, can get a bit anxious about talking about it and it is really sometimes about imagining what you might be like or what you might want when you far less well and I think sometimes as a construct people don't always like to think about that. So stop me at any point if you want to or put the brakes on, and we can we can discuss something completely different. Is that okay? Fine. That's absolutely fine. You're happy to go ahead. Yeah? Yes, of course. Okay, fine. I sometimes kind of approach it in a sort of treatment ladder approach if you're sort of going up the ladder of intensity of treatments. For instance. So for instance, you've been admitted in the past to hospital with things like maybe infections, chest infections or for chemotherapy or for other potential treatments. And I am assuming as of this moment that that is something you would still very much consider. So if you were to develop a pneumonia, for instance, you'd want to come into hospital for intravenous treatments, antibiotics, etc. Yes, definitely. I think that would be appropriate and I would want that. Yeah. And so, you  ...
# ======================================================================
#
# Length: 13204 characters
# Word count: ~2447 words

# %% [markdown]
# ### Step 1.7: Save Transcript to File
# Save the transcript text to the data/transcripts directory.

# %%
folder_name = "data/transcripts"
os.makedirs(folder_name, exist_ok=True)

file_path = os.path.join(folder_name, f"{interaction_id}_transcript.txt")

with open(file_path, "w", encoding="utf-8") as f:
    f.write(transcript_text)

print(f"✓ Transcript saved to: {file_path}")
print(f"File size: {os.path.getsize(file_path)} bytes")
# Out:
# ✓ Transcript saved to: data/transcripts/bdabae9b-efd2-4ff2-9488-b2b3df0b055d_transcript.txt
# File size: 13204 bytes

# %% [markdown]
# ---
# # Step 2: Transcript → Facts
#
# Breaking down the fact extraction process:
# 1. Prepare context payload
# 2. Send extract-facts request
# 3. Display extracted facts
# 4. Save facts to file

# %% [markdown]
# ### Step 2.1: Prepare Context Payload
# Format the transcript text for the extract-facts API.

# %%
output_language = "en-US"

facts_payload = {
    "context": [
        {
            "type": "text",
            "text": transcript_text
        }
    ],
    "outputLanguage": output_language
}

print("Facts extraction payload prepared:")
print(json.dumps(facts_payload, indent=2)[:500] + "..." if len(json.dumps(facts_payload)) > 500 else json.dumps(facts_payload, indent=2))
# Out:
# Facts extraction payload prepared:
# {
#   "context": [
#     {
#       "type": "text",
#       "text": "Afternoon, Kat. Nice to see you. Nice to catch up again. How are you? I'm good. Thank you. How are you? Not too bad. Not too bad. Not too bad. I'm in my office in Wilindra Cancer Hospital as you as you can see. Very nice. And, good to see you, at home as well. The the new world of of, outpatient appointments via via video link, isn't it? Indeed. Yes. Good to catch up with you. I think last time we saw each other face to face. I think th...

# %% [markdown]
# ### Step 2.2: Send Extract-Facts Request
# **API**: `POST /tools/extract-facts`
#
# Call the Corti API to extract structured facts from the transcript.

# %%
print("Extracting facts from transcript...")

response = requests.post(
    f"{client.api_url}/tools/extract-facts",
    headers=headers,
    json=facts_payload,
    timeout=30
)
response.raise_for_status()
facts_result = response.json()

print(f"✓ Facts extracted successfully!")
print(f"Number of facts: {len(facts_result.get('facts', []))}")
# Out:
# Extracting facts from transcript...
# ✓ Facts extracted successfully!
# Number of facts: 15

# %% [markdown]
# ### Step 2.3: Display Extracted Facts
# Show the facts in a readable format.

# %%
facts_list = facts_result.get('facts', [])

print("EXTRACTED FACTS:")
print("=" * 70)
for i, fact in enumerate(facts_list, 1):
    # Handle both string and structured fact formats
    if isinstance(fact, dict):
        fact_text = fact.get('text', str(fact))
        fact_group = fact.get('group', 'N/A')
        fact_source = fact.get('source', 'N/A')
        print(f"{i}. [{fact_group}] {fact_text}")
    else:
        print(f"{i}. {fact}")
print("=" * 70)
print(f"\nTotal facts: {len(facts_list)}")
# Out:
# EXTRACTED FACTS:
# ======================================================================
# 1. [past-medical-history] Stage four breast cancer diagnosis.
# 2. [past-medical-history] Secondary breast cancer spread to lungs and bones.
# 3. [history-of-present-illness] Palliative chemotherapy ongoing for four years.
# 4. [medications-prior-to-visit] Fourth line chemotherapy agent currently used.
# 5. [history-of-present-illness] Pain management initially focused on arm pain.
# 6. [denials-of-symptoms] No current issue with arm pain.
# 7. [past-medical-history] Admitted to hospital for infections and chemotherapy.
# 8. [plan] Willing to receive intravenous treatments for pneumonia.
# 9. [assessment] Continued chemotherapy providing good quality of life.
# 10. [plan] Open to blood transfusions if required.
# 11. [plan] CPR desired if reversible cause and good baseline function.
# 12. [plan] No CPR desired in natural dying process.
# 13. [social-history] Partner agrees with end-of-life care preferences.
# 14. [demographics] Patient is thirty-nine years old.
# 15. [social-history] Enjoys outdoor activities and has a dog.
# ======================================================================
#
# Total facts: 15

# %% [markdown]
# ### Step 2.4: Save Facts to File
# Save the extracted facts to the data/facts directory.

# %%
folder_name = "data/facts"
os.makedirs(folder_name, exist_ok=True)

timestamp = time.strftime("%Y%m%d_%H%M%S")
file_path = os.path.join(folder_name, f"facts_{timestamp}.json")

with open(file_path, "w", encoding="utf-8") as f:
    json.dump(facts_result, f, indent=2, ensure_ascii=False)

print(f"✓ Facts saved to: {file_path}")
print(f"File size: {os.path.getsize(file_path)} bytes")
# Out:
# ✓ Facts saved to: data/facts/facts_20260416_172844.json
# File size: 2701 bytes

# %% [markdown]
# ---
# # Step 3: Facts → SOAP Document
#
# Breaking down the SOAP document generation:
# 1. Format facts for API
# 2. Create document generation request (returns complete document)
# 3. Display SOAP document structure
# 4. Display SOAP sections
# 5. Save document to file

# %% [markdown]
# ### Step 3.1: Format Facts for API
# Convert the facts list into the format required by the documents API.

# %%
# Facts are already properly structured from extract_facts API
# Each fact should have: text, group, source
# If facts are strings (legacy), convert them; otherwise use as-is
formatted_facts = []
for fact in facts_list:
    if isinstance(fact, str):
        # Legacy support: convert string to structured fact
        formatted_facts.append({
            "text": fact,
            "group": "others",
            "source": "core"
        })
    elif isinstance(fact, dict):
        # Use structured fact as-is (already has text, group, source)
        formatted_facts.append(fact)

print(f"Formatted {len(formatted_facts)} facts for document generation")
print("\nSample formatted fact:")
print(json.dumps(formatted_facts[0] if formatted_facts else {}, indent=2))
print("\nAll formatted facts (first 500 chars):")
print(json.dumps(formatted_facts, indent=2)[:500] + "..." if len(json.dumps(formatted_facts)) > 500 else json.dumps(formatted_facts, indent=2))
# Out:
# Formatted 15 facts for document generation
#
# Sample formatted fact:
# {
#   "group": "past-medical-history",
#   "text": "Stage four breast cancer diagnosis.",
#   "value": "Stage four breast cancer diagnosis."
# }
#
# All formatted facts (first 500 chars):
# [
#   {
#     "group": "past-medical-history",
#     "text": "Stage four breast cancer diagnosis.",
#     "value": "Stage four breast cancer diagnosis."
#   },
#   {
#     "group": "past-medical-history",
#     "text": "Secondary breast cancer spread to lungs and bones.",
#     "value": "Secondary breast cancer spread to lungs and bones."
#   },
#   {
#     "group": "history-of-present-illness",
#     "text": "Palliative chemotherapy ongoing for four years.",
#     "value": "Palliative chemotherapy ongoing for four years."...

# %% [markdown]
# ### Step 3.2: Create Document Generation Request
# **API**: `POST /interactions/{id}/documents/`
#
# Submit a request to generate a SOAP document from the facts.

# %%
document_payload = {
    "context": [
        {
            "type": "facts",
            "data": formatted_facts
        }
    ],
    "templateKey": "corti-soap",
    "outputLanguage": output_language,
    "name": "SOAP Note",
    "disableGuardrails": False,
    "documentationMode": "global_sequential"
}

print("Creating SOAP document generation request...")
print(f"Template: {document_payload['templateKey']}")
print(f"Language: {document_payload['outputLanguage']}\n")

response = requests.post(
    f"{client.api_url}/interactions/{interaction_id}/documents/",
    headers=headers,
    json=document_payload,
    timeout=60
)
response.raise_for_status()
soap_document = response.json()

print(f"✓ SOAP document generated!")
print(f"Document ID: {soap_document.get('id', 'N/A')}")
# Out:
# Creating SOAP document generation request...
# Template: corti-soap
# Language: en-US
#
# ✓ SOAP document generated!
# Document ID: ccc968aa-d729-49dd-839a-4ca30c7ca90a

# %% [markdown]
# ### Step 3.4: Retrieve Complete SOAP Document
# View the full SOAP document structure.

# %%
print("SOAP Document Structure:")
print("=" * 70)
print(json.dumps(soap_document, indent=2))
print("=" * 70)
# Out:
# SOAP Document Structure:
# ======================================================================
# {
#   "id": "ccc968aa-d729-49dd-839a-4ca30c7ca90a",
#   "name": "SOAP Note",
#   "templateRef": "corti-soap",
#   "isStream": false,
#   "sections": [
#     {
#       "key": "corti-subjective",
#       "name": "Subjective",
#       "text": "The patient, a thirty-nine-year-old individual, has been diagnosed with stage four breast cancer, which has metastasized to the lungs and bones. She has been undergoing palliative chemotherapy for the past four years and is currently on a fourth-line chemotherapy agent. Initially, she experienced arm pain, which was managed effectively, and she reports no current issues with arm pain. She has been admitted to the hospital for infections and chemotherapy treatments. Despite her condition, she enjoys outdoor activities and has a dog. Her partner supports her end-of-life care preferences.",
#       "sort": 1,
#       "createdAt": "2026-04-16T15:28:48.06915Z",
#       "updatedAt": "2026-04-16T15:28:48.06915Z"
#     },
#     {
#       "key": "corti-objective",
#       "name": "Objective",
#       "text": "Diagnosis: Stage four breast cancer with metastasis to lungs and bones\nChemotherapy: Fourth line agent ongoing\nPain Management: No current arm pain\nHospital Admission: History of admission for infections and chemotherapy\nTreatment Preferences: Intravenous treatments for pneumonia, open to blood transfusions\nCPR Preferences: Desired if reversible cause and good baseline function, not desired in natural dying process",
#       "sort": 2,
#       "createdAt": "2026-04-16T15:28:48.06915Z",
#       "updatedAt": "2026-04-16T15:28:48.06915Z"
#     },
#     {
#       "key": "corti-assessment",
#       "name": "Assessment",
#       "text": "Stage four breast cancer with metastasis to lungs and bones. Ongoing chemotherapy and effective pain management. Palliative care preferences include selective CPR and willingness for intravenous treatments.",
#       "sort": 3,
#       "createdAt": "2026-04-16T15:28:48.06915Z",
#       "updatedAt": "2026-04-16T15:28:48.06915Z"
#     },
#     {
#       "key": "corti-plan",
#       "name": "Plan",
#       "text": "Continue fourth line chemotherapy.\nAdminister intravenous treatments for pneumonia as needed.\nOpen to blood transfusions if required.\nCPR desired if reversible cause and good baseline function. No CPR desired in natural dying process.",
#       "sort": 4,
#       "createdAt": "2026-04-16T15:28:48.06915Z",
#       "updatedAt": "2026-04-16T15:28:48.06915Z"
#     }
#   ],
#   "createdAt": "2026-04-16T15:28:48.06915Z",
#   "updatedAt": "2026-04-16T15:28:48.06915Z",
#   "outputLanguage": "en-US",
#   "usageInfo": {
#     "creditsConsumed": 0.02784
#   }
# }
# ======================================================================

# %% [markdown]
# ### Step 3.5: Display SOAP Sections
# **Result**: Complete clinical documentation in SOAP format

# %%
print("SOAP DOCUMENT:")
print("=" * 70)

if 'sections' in soap_document.keys():
    for chunk in soap_document['sections']:
        section = chunk.get('name')
        content = chunk.get('text', '')
        print(f"\n{section}:")
        print("-" * 70)
        print(content)
else:
    print("No chunks found in document")

print("\n" + "=" * 70)
# Out:
# SOAP DOCUMENT:
# ======================================================================
#
# Subjective:
# ----------------------------------------------------------------------
# The patient, a thirty-nine-year-old individual, has been diagnosed with stage four breast cancer, which has metastasized to the lungs and bones. She has been undergoing palliative chemotherapy for the past four years and is currently on a fourth-line chemotherapy agent. Initially, she experienced arm pain, which was managed effectively, and she reports no current issues with arm pain. She has been admitted to the hospital for infections and chemotherapy treatments. Despite her condition, she enjoys outdoor activities and has a dog. Her partner supports her end-of-life care preferences.
#
# Objective:
# ----------------------------------------------------------------------
# Diagnosis: Stage four breast cancer with metastasis to lungs and bones
# Chemotherapy: Fourth line agent ongoing
# Pain Management: No current arm pain
# Hospital Admission: History of admission for infections and chemotherapy
# Treatment Preferences: Intravenous treatments for pneumonia, open to blood transfusions
# CPR Preferences: Desired if reversible cause and good baseline function, not desired in natural dying process
#
# Assessment:
# ----------------------------------------------------------------------
# Stage four breast cancer with metastasis to lungs and bones. Ongoing chemotherapy and effective pain management. Palliative care preferences include selective CPR and willingness for intravenous treatments.
#
# Plan:
# ----------------------------------------------------------------------
# Continue fourth line chemotherapy.
# Administer intravenous treatments for pneumonia as needed.
# Open to blood transfusions if required.
# CPR desired if reversible cause and good baseline function. No CPR desired in natural dying process.
#
# ======================================================================

# %% [markdown]
# ### Step 3.6: Save SOAP Document to File
# Save the complete SOAP document to the data/SOAP directory.

# %%
folder_name = "data/soap_documents"
os.makedirs(folder_name, exist_ok=True)

file_path = os.path.join(folder_name, f"{interaction_id}_soap.json")

with open(file_path, "w", encoding="utf-8") as f:
    json.dump(soap_document, f, indent=2, ensure_ascii=False)

print(f"✓ SOAP document saved to: {file_path}")
print(f"File size: {os.path.getsize(file_path)} bytes")
# Out:
# ✓ SOAP document saved to: data/soap_documents/bdabae9b-efd2-4ff2-9488-b2b3df0b055d_soap.json
# File size: 2585 bytes

# %% [markdown]
# ---
# # Summary
#
# ## Complete Workflow Recap

# %% [markdown]
# ### Step 1: Audio → Transcript (7 steps)
# 1. ✓ Created interaction
# 2. ✓ Uploaded audio file
# 3. ✓ Requested transcription
# 4. ✓ Polled for completion
# 5. ✓ Retrieved transcript
# 6. ✓ Extracted text
# 7. ✓ Saved to file

# %% [markdown]
# ### Step 2: Transcript → Facts (4 steps)
# 1. ✓ Prepared context payload
# 2. ✓ Sent extract-facts request
# 3. ✓ Displayed facts
# 4. ✓ Saved to file

# %% [markdown]
# ### Step 3: Facts → SOAP (5 steps)
# 1. ✓ Formatted facts for API
# 2. ✓ Created document request (returns complete document)
# 3. ✓ Displayed document structure
# 4. ✓ Displayed SOAP sections
# 5. ✓ Saved to file

# %% [markdown]
# ### Output Files
# - Transcript: `data/transcripts/{interaction_id}_transcript.txt`
# - Facts: `data/facts/facts_{timestamp}.json`
# - SOAP: `data/SOAP/{interaction_id}_soap.json`
#
# ---
#
# **Benefits of this JupyterLab step-by-step approach:**
# - ✅ Each step is independently executable
# - ✅ Easy to identify where issues occur
# - ✅ Can rerun specific steps without starting over
# - ✅ Clear visibility into API requests and responses
# - ✅ Perfect for demos and presentations
